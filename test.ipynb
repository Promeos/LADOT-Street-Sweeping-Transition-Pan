# %%
import arcgis
from arcgis.gis import GIS

arc_id = '51d5f486a30a4c9f9397f31cdaa3ae17'
my_gis = GIS(arc_id)
m = my_gis.map()
m
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-945330381fbe> in <module>
#       3
#       4 arc_id = '51d5f486a30a4c9f9397f31cdaa3ae17'
# ----> 5 my_gis = GIS(arc_id)
#       6 m = my_gis.map()
#       7 m
#
# /opt/anaconda3/envs/arcsgis/lib/python3.7/site-packages/arcgis/gis/__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     350             str(url).lower() not in ["pro", "home"]
#     351         ):
# --> 352             raise Exception("Malformed url provided: %s" % url)
#     353         if username is not None and password is None:
#     354             from getpass import getpass
#
# Exception: Malformed url provided: 51d5f486a30a4c9f9397f31cdaa3ae17

# %%
arcgis.gis.List?
