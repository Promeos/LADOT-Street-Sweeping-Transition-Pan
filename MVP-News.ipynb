# %% [markdown]
# # News and newspaper articles covering parking enforcement.

# %% [markdown]
# News Stations
# - https://www.youtube.com/watch?v=x0LBeYseVYU
# - https://www.youtube.com/watch?v=arNAJ4DgGMk
#
# Newspapers
# - https://thesource.metro.net/2020/10/13/full-parking-enforcement-resumes-on-oct-15-in-city-of-los-angeles/
# - https://ktla.com/news/local-news/l-a-s-relaxed-parking-enforcement-ends-oct-15-street-sweeping-enforcement-to-resume/
# - https://www.latimes.com/california/story/2020-10-15/street-sweeping-parking-enforcement-resumes-today

# %% [markdown]
# Business Goals
# 1. Determine if news stations and newspapers/articles effectively informed the public of continued parking enforcement on 10/15/2020.
#
# 2. If witness testimony is available, determine sentiment.
#
# Process
#
# [x] Check again to see if there are news reports that I may have missed.
# - Use an audio-to-text transcriber and use NLP techniques to detect theme or sentiment.
#     - Find open source Python library for audio-to-text transcription.
# - Collect total number of subscibers for each publication if available.
# - Collect demographic data of Los Angeles to determine a rough estimate of adults with social media accounts or newpaper subscriptions.
#
# Ideas
# - Use demographic information to determine if the most vunerable Angelenos (Low-income) were affected more than affluent Angelenos.
# - Learn spatial statitics.
# - Find Python library with spatial statistics.

# %% [markdown]
# Missed publications
# - https://www.venicecurrent.com/news/local/full-parking-enforcement-resumes-today/article_729c3dbc-029b-544b-9e85-aa2c5dbcbab6.html
# - https://www.venicepaparazzi.com/2020/10/07/laparking2020/
# - https://spectrumnews1.com/ca/la-west/transportation/2020/10/14/ladot-will-resume-street-sweeping-and-other-parking-enforcement-thursday
